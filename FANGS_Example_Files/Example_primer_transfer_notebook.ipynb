# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns


from FANGS import * #import tools from FANGS library

# %% [markdown]
# ### Input the example primer file
# #### The file has 4 tabs "source plate", "F_destination", "R_destination", and "code". Adjust your plate setuo within these files

# %%
primer_input_file = 'Example_Primers_96.xlsx'
primer_output_file = "example_primer_transfer.csv" #give the output file a unique name

# %%
set_up = Set_up(primer_input_file, plate_size=384)

# %%
Primer_transfer = set_up.PCR_set_up()
Primer_transfer
# Out:
#    Part Name Destination Well Source Well Transfer Volume Sample type
# 0       i701               A1          A1             150      primer
# 1       i701               C1          A1             150      primer
# 2       i701               E1          A1             150      primer
# 3       i701               G1          A1             150      primer
# 4       i701               I1          A1             150      primer
# 5       i701               K1          A1             150      primer
# 6       i701               M1          A1             150      primer
# 7       i701               O1          A1             150      primer
# 8       i702               A3          A3             150      primer
# 9       i702               C3          A3             150      primer
# 10      i702               E3          A3             150      primer
# 11      i702               G3          A3             150      primer
# ...

# %% [markdown]
# ### finally, save the file to a .csv

# %%
Primer_transfer.to_csv(primer_output_file)
